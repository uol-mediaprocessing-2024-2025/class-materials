# %% [markdown]
# <a href="https://colab.research.google.com/github/uol-mediaprocessing/notebooks/blob/master/python-exercises-solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Exercises

# %% [markdown]
# ## 1 - Calculate the average of the following array

# %%
array = [2, 6, 4, 8, 7, 3, 4]

# %%
sum(array) / len(array)
# Out:
# 4.857142857142857

# %% [markdown]
# ## 2 - Concatenate the two following arrays.

# %%
array_1 = [2, 6, 13]
array_2 = [9, 8, 12, 42]

# %%
array_1 + array_2
# Out:
# [2, 6, 13, 9, 8, 12, 42]

# %% [markdown]
# ## 3 - NumPy arrays as images

# %% [markdown]
# ##### **3.1** Create a black image with 100x100 pixels (**numpy** array of zeros)

# %%
import numpy as np
array = np.zeros((100, 100))

# %% [markdown]
# ##### **3.2** Set the top-right 50x50 pixels of the image to white (255)

# %%
array[:50, 50:] = 255

# %% [markdown]
# ##### **3.3** Display the image with **matplotlib**

# %%
import matplotlib.pyplot as plt
plt.imshow(array, cmap="gray")

# %% [markdown]
# ##### **3.4** Draw a circle in the center of the image (50 pixel diameter)

# %%
import math
for row in range(len(array)):
    for col in range(len(array)):
        dist_from_center_row = 50 - row
        dist_from_center_col = 50 - col
        dist_from_center = math.sqrt(dist_from_center_row ** 2 + dist_from_center_col ** 2)
        if(dist_from_center < 25):
            array[row][col] = 255

# %%
plt.imshow(array, cmap="gray")

# %% [markdown]
# ## 4 - OpenCV Images

# %% [markdown]
# ##### **4.1** Load the image from this URL: https://raw.githubusercontent.com/uol-mediaprocessing/notebooks/master/pictures/image36.jpg

# %%
! wget https://raw.githubusercontent.com/uol-mediaprocessing/notebooks/master/pictures/image36.jpg

import cv2
img = cv2.imread("image36.jpg")
# Out:
# --2019-10-27 22:53:25--  https://raw.githubusercontent.com/uol-mediaprocessing/notebooks/master/pictures/image36.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 464504 (454K) [image/jpeg]
# Saving to: ‘image36.jpg’
#
# image36.jpg         100%[===================>] 453.62K  --.-KB/s    in 0.06s
#
# 2019-10-27 22:53:25 (7.04 MB/s) - ‘image36.jpg’ saved [464504/464504]

# %% [markdown]
# ##### **4.2** Convert the image from the BGR format to RGB

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ##### **4.3** Display the image with **matplotlib**

# %%
plt.imshow(img)

# %% [markdown]
# ##### **4.4** Display the **red** channel in grayscale with **matplotlib**

# %%
plt.imshow(img[..., 0], cmap="gray")
