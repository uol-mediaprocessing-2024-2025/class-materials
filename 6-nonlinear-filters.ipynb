# %% [markdown]
# <a href="https://colab.research.google.com/github/uol-mediaprocessing/notebooks/blob/master/6-nonlinear-filters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Non-linear Filters

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2
from skimage import filters
plt.rcParams["figure.figsize"] = (10, 10)

# %% [markdown]
# A non-linear filter is a filter whose output is not a linear function of its input.

# %%
! wget -q https://raw.githubusercontent.com/uol-mediaprocessing/notebooks/master/pictures/Lenna.png
img = cv2.imread("Lenna.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %% [markdown]
# # Median Filter
# The Median Filter is a non-linear filter, often used to remove noise from an image. Its perceptive field moves over the image and outputs the mean of the current field as a pixel of the result.

# %%
minimum = cv2.medianBlur(img, 7)
plt.imshow(minimum)

# %% [markdown]
# # Bilateral Filter
# This filter is highly effective in noise removal while keeping edges sharp. It replaces the intensity of each pixel with a weighted average of intensity values from nearby pixels. This weight can be based on a Gaussian distribution. Crucially, the weights depend not only on Euclidean distance of pixels, but also on the radiometric differences (e.g., range differences, such as color intensity, depth distance, etc.). This preserves sharp edges.

# %%
bilateral = cv2.bilateralFilter(img, 9, 75, 75)
plt.imshow(bilateral)
